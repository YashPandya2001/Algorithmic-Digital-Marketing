# %%
# Numpy for loading image feature vectors from file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# json for storing data in json file
import json

# Annoy and Scipy for similarity calculation
from annoy import AnnoyIndex
from scipy import spatial

# %%
def match_id(filename):
  with open("/content/drive/My Drive/Algorithmic Digital Marketing/Assignment 2/Dataset/fin.json") as json_file:
    
    for file in json_file:
        seen = json.loads(file)

        for line in seen:
          
          if filename==line['imageName']:
            
            print(line)
            return line['productId']
            break

# %%
def cluster():

  start_time = time.time()
  
  print("---------------------------------")
  print ("Step.1 - ANNOY index generation - Started at %s" %time.ctime())
  print("---------------------------------")

  # Defining data structures as empty dict
  file_index_to_file_name = {}
  file_index_to_file_vector = {}
  file_index_to_product_id = {}

  # Configuring annoy parameters
  dims = 1792
  n_nearest_neighbors = 20
  trees = 10000

  # Reads all file names which stores feature vectors 
  allfiles = glob.glob('/content/drive/My Drive/Algorithmic Digital Marketing/Assignment 2/Dataset/Vector_SS3/*.npz')

  t = AnnoyIndex(dims, metric='angular')

  for file_index, i in enumerate(allfiles):
    
    # Reads feature vectors and assigns them into the file_vector 
    file_vector = np.loadtxt(i)

    # Assigns file_name, feature_vectors and corresponding product_id
    file_name = os.path.basename(i).split('.')[0]
    file_index_to_file_name[file_index] = file_name
    file_index_to_file_vector[file_index] = file_vector
    file_index_to_product_id[file_index] = match_id(file_name)

    # Adds image feature vectors into annoy index   
    t.add_item(file_index, file_vector)

    print("---------------------------------")
    print("Annoy index     : %s" %file_index)
    print("Image file name : %s" %file_name)
    print("Product id      : %s" %file_index_to_product_id[file_index])
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))


  # Builds annoy index
  t.build(trees)

  print ("Step.1 - ANNOY index generation - Finished")
  print ("Step.2 - Similarity score calculation - Started ") 
  
  named_nearest_neighbors = []

  # Loops through all indexed items
  for i in file_index_to_file_name.keys():

    # Assigns master file_name, image feature vectors and product id values
    master_file_name = file_index_to_file_name[i]
    master_vector = file_index_to_file_vector[i]
    master_product_id = file_index_to_product_id[i]

    # Calculates the nearest neighbors of the master item
    nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)

    # Loops through the nearest neighbors of the master item
    for j in nearest_neighbors:

      print(j)

      # Assigns file_name, image feature vectors and product id values of the similar item
      neighbor_file_name = file_index_to_file_name[j]
      neighbor_file_vector = file_index_to_file_vector[j]
      neighbor_product_id = file_index_to_product_id[j]

      # Calculates the similarity score of the similar item
      similarity = 1 - spatial.distance.cosine(master_vector, neighbor_file_vector)
      rounded_similarity = int((similarity * 10000)) / 10000.0

      # Appends master product id with the similarity score 
      # and the product id of the similar items
      named_nearest_neighbors.append({
        'similarity': rounded_similarity,
        'master_pi': master_product_id,
        'similar_pi': neighbor_product_id})

    print("---------------------------------") 
    print("Similarity index       : %s" %i)
    print("Master Image file name : %s" %file_index_to_file_name[i]) 
    print("Nearest Neighbors.     : %s" %nearest_neighbors) 
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  
  print ("Step.2 - Similarity score calculation - Finished ") 

  # Writes the 'named_nearest_neighbors' to a json file
  with open('nearest_neighbors.json', 'w') as out:
    json.dump(named_nearest_neighbors, out)

  print ("Step.3 - Data stored in 'nearest_neighbors.json' file ") 
  print("--- Prosess completed in %.2f minutes ---------" % ((time.time() - start_time)/60))

cluster()
# Out:
# ---------------------------------
# Step.1 - ANNOY index generation - Started at Fri Jul 10 20:45:56 2020
# ---------------------------------
# {'imageName': '33_0', 'productId': '36'}
# ---------------------------------
# Annoy index     : 0
# Image file name : 33_0
# Product id      : 36
# --- 0.01 minutes passed ---------
# {'imageName': '45_0', 'productId': '53'}
# ---------------------------------
# Annoy index     : 1
# Image file name : 45_0
# Product id      : 53
# --- 0.01 minutes passed ---------
# {'imageName': '25_0', 'productId': '25'}
# ---------------------------------
# Annoy index     : 2
# Image file name : 25_0
# Product id      : 25
# --- 0.02 minutes passed ---------
# {'imageName': '61_0', 'productId': '70'}
# ---------------------------------
# Annoy index     : 3
# Image file name : 61_0
# Product id      : 70
# --- 0.02 minutes passed ---------
# {'imageName': '72_0', 'productId': '81'}
# ---------------------------------
# Annoy index     : 4
# Image file name : 72_0
# Product id      : 81
# --- 0.03 minutes passed ---------
# {'imageName': '13_2', 'productId': '15'}
# ---------------------------------
# Annoy index     : 5
# Image file name : 13_2
# Product id      : 15
# --- 0.03 minutes passed ---------
# {'imageName': '60_0', 'productId': '69'}
# ---------------------------------
# Annoy index     : 6
# Image file name : 60_0
# Product id      : 69
# --- 0.03 minutes passed ---------
# {'imageName': '64_0', 'productId': '74'}
# ---------------------------------
# Annoy index     : 7
# Image file name : 64_0
# Product id      : 74
# --- 0.04 minutes passed ---------
# {'imageName': '25_1', 'productId': '26'}
# ---------------------------------
# Annoy index     : 8
# Image file name : 25_1
# Product id      : 26
# --- 0.05 minutes passed ---------
# {'imageName': '19_0', 'productId': '21'}
# ---------------------------------
# Annoy index     : 9
# Image file name : 19_0
# Product id      : 21
# --- 0.05 minutes passed ---------
# {'imageName': '33_1', 'productId': '37'}
# ---------------------------------
# Annoy index     : 10
# Image file name : 33_1
# Product id      : 37
# --- 0.06 minutes passed ---------
# {'imageName': '50_0', 'productId': '57'}
# ---------------------------------
# Annoy index     : 11
# Image file name : 50_0
# Product id      : 57
# --- 0.06 minutes passed ---------
# {'imageName': '43_2', 'productId': '51'}
# ---------------------------------
# Annoy index     : 12
# Image file name : 43_2
# Product id      : 51
# --- 0.07 minutes passed ---------
# {'imageName': '9_0', 'productId': '10'}
# ---------------------------------
# Annoy index     : 13
# Image file name : 9_0
# Product id      : 10
# --- 0.07 minutes passed ---------
# {'imageName': '26_1', 'productId': '30'}
# ---------------------------------
# Annoy index     : 14
# Image file name : 26_1
# Product id      : 30
# --- 0.07 minutes passed ---------
# {'imageName': '38_0', 'productId': '42'}
# ---------------------------------
# Annoy index     : 15
# Image file name : 38_0
# Product id      : 42
# --- 0.08 minutes passed ---------
# {'imageName': '73_1', 'productId': '83'}
# ---------------------------------
# Annoy index     : 16
# Image file name : 73_1
# Product id      : 83
# --- 0.08 minutes passed ---------
# {'imageName': '48_0', 'productId': '56'}
# ---------------------------------
# Annoy index     : 17
# Image file name : 48_0
# Product id      : 56
# --- 0.09 minutes passed ---------
# {'imageName': '57_1', 'productId': '65'}
# ---------------------------------
# Annoy index     : 18
# Image file name : 57_1
# Product id      : 65
# --- 0.10 minutes passed ---------
# {'imageName': '25_2', 'productId': '27'}
# ---------------------------------
# Annoy index     : 19
# Image file name : 25_2
# Product id      : 27
# --- 0.10 minutes passed ---------
# ---------------------------------
# Annoy index     : 20
# Image file name : 40_0
# Product id      : None
# --- 0.11 minutes passed ---------
# {'imageName': '39_0', 'productId': '43'}
# ---------------------------------
# Annoy index     : 21
# Image file name : 39_0
# Product id      : 43
# --- 0.11 minutes passed ---------
# {'imageName': '52_0', 'productId': '59'}
# ---------------------------------
# Annoy index     : 22
# Image file name : 52_0
# Product id      : 59
# --- 0.11 minutes passed ---------
# {'imageName': '53_0', 'productId': '60'}
# ---------------------------------
# Annoy index     : 23
# Image file name : 53_0
# Product id      : 60
# --- 0.12 minutes passed ---------
# {'imageName': '34_0', 'productId': '38'}
# ---------------------------------
# Annoy index     : 24
# Image file name : 34_0
# Product id      : 38
# --- 0.13 minutes passed ---------
# {'imageName': '57_0', 'productId': '64'}
# ---------------------------------
# Annoy index     : 25
# Image file name : 57_0
# Product id      : 64
# --- 0.13 minutes passed ---------
# {'imageName': '43_0', 'productId': '49'}
# ---------------------------------
# Annoy index     : 26
# Image file name : 43_0
# Product id      : 49
# --- 0.13 minutes passed ---------
# {'imageName': '70_0', 'productId': '79'}
# ---------------------------------
# Annoy index     : 27
# Image file name : 70_0
# Product id      : 79
# --- 0.14 minutes passed ---------
# {'imageName': '20_0', 'productId': '23'}
# ---------------------------------
# Annoy index     : 28
# Image file name : 20_0
# Product id      : 23
# --- 0.14 minutes passed ---------
# {'imageName': '5_0', 'productId': '6'}
# ---------------------------------
# Annoy index     : 29
# Image file name : 5_0
# Product id      : 6
# --- 0.15 minutes passed ---------
# {'imageName': '11_0', 'productId': '11'}
# ---------------------------------
# Annoy index     : 30
# Image file name : 11_0
# Product id      : 11
# --- 0.15 minutes passed ---------
# {'imageName': '62_1', 'productId': '72'}
# ---------------------------------
# Annoy index     : 31
# Image file name : 62_1
# Product id      : 72
# --- 0.16 minutes passed ---------
# {'imageName': '7_0', 'productId': '8'}
# ---------------------------------
# Annoy index     : 32
# Image file name : 7_0
# Product id      : 8
# --- 0.16 minutes passed ---------
# {'imageName': '44_0', 'productId': '52'}
# ---------------------------------
# Annoy index     : 33
# Image file name : 44_0
# Product id      : 52
# --- 0.17 minutes passed ---------
# {'imageName': '26_2', 'productId': '31'}
# ---------------------------------
# Annoy index     : 34
# Image file name : 26_2
# Product id      : 31
# --- 0.17 minutes passed ---------
# {'imageName': '47_0', 'productId': '55'}
# ---------------------------------
# Annoy index     : 35
# Image file name : 47_0
# Product id      : 55
# --- 0.17 minutes passed ---------
# {'imageName': '41_0', 'productId': '46'}
# ---------------------------------
# Annoy index     : 36
# Image file name : 41_0
# Product id      : 46
# --- 0.18 minutes passed ---------
# {'imageName': '8_0', 'productId': '9'}
# ---------------------------------
# Annoy index     : 37
# Image file name : 8_0
# Product id      : 9
# --- 0.18 minutes passed ---------
# {'imageName': '59_0', 'productId': '68'}
# ---------------------------------
# Annoy index     : 38
# Image file name : 59_0
# Product id      : 68
# --- 0.19 minutes passed ---------
# {'imageName': '30_0', 'productId': '34'}
# ---------------------------------
# Annoy index     : 39
# Image file name : 30_0
# Product id      : 34
# --- 0.19 minutes passed ---------
# {'imageName': '26_0', 'productId': '29'}
# ---------------------------------
# Annoy index     : 40
# Image file name : 26_0
# Product id      : 29
# --- 0.19 minutes passed ---------
# {'imageName': '15_0', 'productId': '17'}
# ---------------------------------
# Annoy index     : 41
# Image file name : 15_0
# Product id      : 17
# --- 0.20 minutes passed ---------
# {'imageName': '13_1', 'productId': '14'}
# ---------------------------------
# Annoy index     : 42
# Image file name : 13_1
# Product id      : 14
# --- 0.20 minutes passed ---------
# {'imageName': '58_0', 'productId': '67'}
# ---------------------------------
# Annoy index     : 43
# Image file name : 58_0
# Product id      : 67
# --- 0.20 minutes passed ---------
# {'imageName': '35_0', 'productId': '39'}
# ---------------------------------
# Annoy index     : 44
# Image file name : 35_0
# Product id      : 39
# --- 0.21 minutes passed ---------
# {'imageName': '26_3', 'productId': '32'}
# ---------------------------------
# Annoy index     : 45
# Image file name : 26_3
# Product id      : 32
# --- 0.21 minutes passed ---------
# {'imageName': '39_1', 'productId': '44'}
# ---------------------------------
# Annoy index     : 46
# Image file name : 39_1
# Product id      : 44
# --- 0.22 minutes passed ---------
# {'imageName': '4_0', 'productId': '5'}
# ---------------------------------
# Annoy index     : 47
# Image file name : 4_0
# Product id      : 5
# --- 0.22 minutes passed ---------
# {'imageName': '71_0', 'productId': '80'}
# ---------------------------------
# Annoy index     : 48
# Image file name : 71_0
# Product id      : 80
# --- 0.23 minutes passed ---------
# {'imageName': '13_0', 'productId': '13'}
# ---------------------------------
# Annoy index     : 49
# Image file name : 13_0
# Product id      : 13
# --- 0.23 minutes passed ---------
# {'imageName': '12_0', 'productId': '12'}
# ---------------------------------
# Annoy index     : 50
# Image file name : 12_0
# Product id      : 12
# --- 0.24 minutes passed ---------
# {'imageName': '19_1', 'productId': '22'}
# ---------------------------------
# Annoy index     : 51
# Image file name : 19_1
# Product id      : 22
# --- 0.24 minutes passed ---------
# {'imageName': '16_0', 'productId': '18'}
# ---------------------------------
# Annoy index     : 52
# Image file name : 16_0
# Product id      : 18
# --- 0.24 minutes passed ---------
# {'imageName': '18_0', 'productId': '20'}
# ---------------------------------
# Annoy index     : 53
# Image file name : 18_0
# Product id      : 20
# --- 0.25 minutes passed ---------
# {'imageName': '73_0', 'productId': '82'}
# ---------------------------------
# Annoy index     : 54
# Image file name : 73_0
# Product id      : 82
# --- 0.25 minutes passed ---------
# {'imageName': '6_0', 'productId': '7'}
# ---------------------------------
# Annoy index     : 55
# Image file name : 6_0
# Product id      : 7
# --- 0.25 minutes passed ---------
# {'imageName': '77_0', 'productId': '90'}
# ---------------------------------
# Annoy index     : 56
# Image file name : 77_0
# Product id      : 90
# --- 0.26 minutes passed ---------
# {'imageName': '17_0', 'productId': '19'}
# ---------------------------------
# Annoy index     : 57
# Image file name : 17_0
# Product id      : 19
# --- 0.26 minutes passed ---------
# {'imageName': '76_0', 'productId': '88'}
# ---------------------------------
# Annoy index     : 58
# Image file name : 76_0
# Product id      : 88
# --- 0.26 minutes passed ---------
# {'imageName': '64_2', 'productId': '76'}
# ---------------------------------
# Annoy index     : 59
# Image file name : 64_2
# Product id      : 76
# --- 0.27 minutes passed ---------
# {'imageName': '1_0', 'productId': '2'}
# ---------------------------------
# Annoy index     : 60
# Image file name : 1_0
# Product id      : 2
# --- 0.27 minutes passed ---------
# {'imageName': '55_0', 'productId': '62'}
# ---------------------------------
# Annoy index     : 61
# Image file name : 55_0
# Product id      : 62
# --- 0.28 minutes passed ---------
# {'imageName': '54_0', 'productId': '61'}
# ---------------------------------
# Annoy index     : 62
# Image file name : 54_0
# Product id      : 61
# --- 0.28 minutes passed ---------
# {'imageName': '42_1', 'productId': '48'}
# ---------------------------------
# Annoy index     : 63
# Image file name : 42_1
# Product id      : 48
# --- 0.28 minutes passed ---------
# {'imageName': '13_3', 'productId': '16'}
# ---------------------------------
# Annoy index     : 64
# Image file name : 13_3
# Product id      : 16
# --- 0.29 minutes passed ---------
# {'imageName': '64_1', 'productId': '75'}
# ---------------------------------
# Annoy index     : 65
# Image file name : 64_1
# Product id      : 75
# --- 0.29 minutes passed ---------
# {'imageName': '42_0', 'productId': '47'}
# ---------------------------------
# Annoy index     : 66
# Image file name : 42_0
# Product id      : 47
# --- 0.30 minutes passed ---------
# {'imageName': '51_0', 'productId': '58'}
# ---------------------------------
# Annoy index     : 67
# Image file name : 51_0
# Product id      : 58
# --- 0.30 minutes passed ---------
# {'imageName': '3_0', 'productId': '4'}
# ---------------------------------
# Annoy index     : 68
# Image file name : 3_0
# Product id      : 4
# --- 0.30 minutes passed ---------
# {'imageName': '31_0', 'productId': '35'}
# ---------------------------------
# Annoy index     : 69
# Image file name : 31_0
# Product id      : 35
# --- 0.31 minutes passed ---------
# {'imageName': '22_0', 'productId': '24'}
# ---------------------------------
# Annoy index     : 70
# Image file name : 22_0
# Product id      : 24
# --- 0.31 minutes passed ---------
# {'imageName': '80_0', 'productId': '92'}
# ---------------------------------
# Annoy index     : 71
# Image file name : 80_0
# Product id      : 92
# --- 0.32 minutes passed ---------
# {'imageName': '36_0', 'productId': '40'}
# ---------------------------------
# Annoy index     : 72
# Image file name : 36_0
# Product id      : 40
# --- 0.32 minutes passed ---------
# {'imageName': '37_0', 'productId': '41'}
# ---------------------------------
# Annoy index     : 73
# Image file name : 37_0
# Product id      : 41
# --- 0.32 minutes passed ---------
# {'imageName': '0_0', 'productId': '1'}
# ---------------------------------
# Annoy index     : 74
# Image file name : 0_0
# Product id      : 1
# --- 0.33 minutes passed ---------
# {'imageName': '62_0', 'productId': '71'}
# ---------------------------------
# Annoy index     : 75
# Image file name : 62_0
# Product id      : 71
# --- 0.33 minutes passed ---------
# {'imageName': '2_0', 'productId': '3'}
# ---------------------------------
# Annoy index     : 76
# Image file name : 2_0
# Product id      : 3
# --- 0.33 minutes passed ---------
# {'imageName': '46_0', 'productId': '54'}
# ---------------------------------
# Annoy index     : 77
# Image file name : 46_0
# Product id      : 54
# --- 0.34 minutes passed ---------
# {'imageName': '28_0', 'productId': '33'}
# ---------------------------------
# Annoy index     : 78
# Image file name : 28_0
# Product id      : 33
# --- 0.34 minutes passed ---------
# {'imageName': '43_1', 'productId': '50'}
# ---------------------------------
# Annoy index     : 79
# Image file name : 43_1
# Product id      : 50
# --- 0.35 minutes passed ---------
# {'imageName': '57_2', 'productId': '66'}
# ---------------------------------
# Annoy index     : 80
# Image file name : 57_2
# Product id      : 66
# --- 0.35 minutes passed ---------
# ---------------------------------
# Annoy index     : 81
# Image file name : 97_1
# Product id      : None
# --- 0.36 minutes passed ---------
# {'imageName': '91_0', 'productId': '100'}
# ---------------------------------
# Annoy index     : 82
# Image file name : 91_0
# Product id      : 100
# --- 0.36 minutes passed ---------
# {'imageName': '25_3', 'productId': '28'}
# ---------------------------------
# Annoy index     : 83
# Image file name : 25_3
# Product id      : 28
# --- 0.37 minutes passed ---------
# {'imageName': '99_0', 'productId': '108'}
# ---------------------------------
# Annoy index     : 84
# Image file name : 99_0
# Product id      : 108
# --- 0.37 minutes passed ---------
# {'imageName': '89_0', 'productId': '98'}
# ---------------------------------
# Annoy index     : 85
# Image file name : 89_0
# Product id      : 98
# --- 0.38 minutes passed ---------
# {'imageName': '76_1', 'productId': '89'}
# ---------------------------------
# Annoy index     : 86
# Image file name : 76_1
# Product id      : 89
# --- 0.38 minutes passed ---------
# {'imageName': '87_0', 'productId': '96'}
# ---------------------------------
# Annoy index     : 87
# Image file name : 87_0
# Product id      : 96
# --- 0.39 minutes passed ---------
# {'imageName': '73_2', 'productId': '84'}
# ---------------------------------
# Annoy index     : 88
# Image file name : 73_2
# Product id      : 84
# --- 0.39 minutes passed ---------
# {'imageName': '81_0', 'productId': '93'}
# ---------------------------------
# Annoy index     : 89
# Image file name : 81_0
# Product id      : 93
# --- 0.40 minutes passed ---------
# {'imageName': '98_0', 'productId': '104'}
# ---------------------------------
# Annoy index     : 90
# Image file name : 98_0
# Product id      : 104
# --- 0.41 minutes passed ---------
# {'imageName': '95_0', 'productId': '102'}
# ---------------------------------
# Annoy index     : 91
# Image file name : 95_0
# Product id      : 102
# --- 0.41 minutes passed ---------
# {'imageName': '73_3', 'productId': '85'}
# ---------------------------------
# Annoy index     : 92
# Image file name : 73_3
# Product id      : 85
# --- 0.42 minutes passed ---------
# {'imageName': '69_0', 'productId': '78'}
# ---------------------------------
# Annoy index     : 93
# Image file name : 69_0
# Product id      : 78
# --- 0.43 minutes passed ---------
# {'imageName': '63_0', 'productId': '73'}
# ---------------------------------
# Annoy index     : 94
# Image file name : 63_0
# Product id      : 73
# --- 0.43 minutes passed ---------
# {'imageName': '90_0', 'productId': '99'}
# ---------------------------------
# Annoy index     : 95
# Image file name : 90_0
# Product id      : 99
# --- 0.43 minutes passed ---------
# {'imageName': '75_0', 'productId': '87'}
# ---------------------------------
# Annoy index     : 96
# Image file name : 75_0
# Product id      : 87
# --- 0.44 minutes passed ---------
# {'imageName': '97_0', 'productId': '103'}
# ---------------------------------
# Annoy index     : 97
# Image file name : 97_0
# Product id      : 103
# --- 0.44 minutes passed ---------
# {'imageName': '84_0', 'productId': '95'}
# ---------------------------------
# Annoy index     : 98
# Image file name : 84_0
# Product id      : 95
# --- 0.44 minutes passed ---------
# {'imageName': '98_3', 'productId': '107'}
# ---------------------------------
# Annoy index     : 99
# Image file name : 98_3
# Product id      : 107
# --- 0.45 minutes passed ---------
# {'imageName': '56_0', 'productId': '63'}
# ---------------------------------
# Annoy index     : 100
# Image file name : 56_0
# Product id      : 63
# --- 0.45 minutes passed ---------
# {'imageName': '66_0', 'productId': '77'}
# ---------------------------------
# Annoy index     : 101
# Image file name : 66_0
# Product id      : 77
# --- 0.46 minutes passed ---------
# {'imageName': '79_0', 'productId': '91'}
# ---------------------------------
# Annoy index     : 102
# Image file name : 79_0
# Product id      : 91
# --- 0.46 minutes passed ---------
# {'imageName': '83_0', 'productId': '94'}
# ---------------------------------
# Annoy index     : 103
# Image file name : 83_0
# Product id      : 94
# --- 0.46 minutes passed ---------
# {'imageName': '98_1', 'productId': '105'}
# ---------------------------------
# Annoy index     : 104
# Image file name : 98_1
# Product id      : 105
# --- 0.47 minutes passed ---------
# {'imageName': '101_0', 'productId': '109'}
# ---------------------------------
# Annoy index     : 105
# Image file name : 101_0
# Product id      : 109
# --- 0.47 minutes passed ---------
# {'imageName': '74_0', 'productId': '86'}
# ---------------------------------
# Annoy index     : 106
# Image file name : 74_0
# Product id      : 86
# --- 0.47 minutes passed ---------
# {'imageName': '98_2', 'productId': '106'}
# ---------------------------------
# Annoy index     : 107
# Image file name : 98_2
# Product id      : 106
# --- 0.48 minutes passed ---------
# {'imageName': '88_0', 'productId': '97'}
# ---------------------------------
# Annoy index     : 108
# Image file name : 88_0
# Product id      : 97
# --- 0.48 minutes passed ---------
# {'imageName': '92_0', 'productId': '101'}
# ---------------------------------
# Annoy index     : 109
# Image file name : 92_0
# Product id      : 101
# --- 0.48 minutes passed ---------
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started
# 0
# 10
# 46
# 21
# 91
# 83
# 26
# 12
# 79
# 89
# 31
# 68
# 32
# 16
# 81
# 75
# 76
# 70
# 9
# 54
# ---------------------------------
# Similarity index       : 0
# Master Image file name : 33_0
# Nearest Neighbors.     : [0, 10, 46, 21, 91, 83, 26, 12, 79, 89, 31, 68, 32, 16, 81, 75, 76, 70, 9, 54]
# --- 0.49 minutes passed ---------
# 1
# 18
# 42
# 25
# 80
# 49
# 64
# 58
# 55
# 81
# 4
# 98
# 43
# 79
# 5
# 26
# 77
# 83
# 74
# 0
# ---------------------------------
# Similarity index       : 1
# Master Image file name : 45_0
# Nearest Neighbors.     : [1, 18, 42, 25, 80, 49, 64, 58, 55, 81, 4, 98, 43, 79, 5, 26, 77, 83, 74, 0]
# --- 0.49 minutes passed ---------
# 2
# 19
# 8
# 51
# 20
# 41
# 65
# 78
# 35
# 14
# 33
# 24
# 28
# 71
# 88
# 72
# 95
# 74
# 106
# 104
# ---------------------------------
# Similarity index       : 2
# Master Image file name : 25_0
# Nearest Neighbors.     : [2, 19, 8, 51, 20, 41, 65, 78, 35, 14, 33, 24, 28, 71, 88, 72, 95, 74, 106, 104]
# --- 0.49 minutes passed ---------
# 3
# 37
# 106
# 30
# 20
# 35
# 33
# 67
# 36
# 39
# 101
# 24
# 107
# 102
# 52
# 88
# 51
# 22
# 72
# 15
# ---------------------------------
# Similarity index       : 3
# Master Image file name : 61_0
# Nearest Neighbors.     : [3, 37, 106, 30, 20, 35, 33, 67, 36, 39, 101, 24, 107, 102, 52, 88, 51, 22, 72, 15]
# --- 0.49 minutes passed ---------
# 4
# 92
# 88
# 37
# 101
# 54
# 58
# 42
# 60
# 104
# 3
# 16
# 90
# 43
# 83
# 107
# 49
# 30
# 76
# 80
# ---------------------------------
# Similarity index       : 4
# Master Image file name : 72_0
# Nearest Neighbors.     : [4, 92, 88, 37, 101, 54, 58, 42, 60, 104, 3, 16, 90, 43, 83, 107, 49, 30, 76, 80]
# --- 0.49 minutes passed ---------
# 5
# 64
# 49
# 79
# 81
# 97
# 26
# 0
# 10
# 55
# 38
# 1
# 12
# 91
# 98
# 25
# 31
# 68
# 48
# 18
# ---------------------------------
# Similarity index       : 5
# Master Image file name : 13_2
# Nearest Neighbors.     : [5, 64, 49, 79, 81, 97, 26, 0, 10, 55, 38, 1, 12, 91, 98, 25, 31, 68, 48, 18]
# --- 0.49 minutes passed ---------
# 6
# 85
# 24
# 102
# 56
# 33
# 36
# 94
# 96
# 106
# 22
# 15
# 101
# 86
# 95
# 39
# 72
# 30
# 69
# 20
# ---------------------------------
# Similarity index       : 6
# Master Image file name : 60_0
# Nearest Neighbors.     : [6, 85, 24, 102, 56, 33, 36, 94, 96, 106, 22, 15, 101, 86, 95, 39, 72, 30, 69, 20]
# --- 0.49 minutes passed ---------
# 7
# 101
# 92
# 52
# 54
# 86
# 33
# 88
# 27
# 30
# 94
# 84
# 47
# 50
# 3
# 76
# 16
# 56
# 65
# 67
# ---------------------------------
# Similarity index       : 7
# Master Image file name : 64_0
# Nearest Neighbors.     : [7, 101, 92, 52, 54, 86, 33, 88, 27, 30, 94, 84, 47, 50, 3, 76, 16, 56, 65, 67]
# --- 0.49 minutes passed ---------
# 8
# 20
# 22
# 33
# 2
# 102
# 35
# 19
# 3
# 36
# 15
# 106
# 67
# 24
# 69
# 6
# 14
# 86
# 52
# 96
# ---------------------------------
# Similarity index       : 8
# Master Image file name : 25_1
# Nearest Neighbors.     : [8, 20, 22, 33, 2, 102, 35, 19, 3, 36, 15, 106, 67, 24, 69, 6, 14, 86, 52, 96]
# --- 0.49 minutes passed ---------
# 9
# 16
# 76
# 0
# 10
# 31
# 91
# 106
# 67
# 32
# 33
# 70
# 72
# 46
# 19
# 89
# 68
# 14
# 51
# 93
# ---------------------------------
# Similarity index       : 9
# Master Image file name : 19_0
# Nearest Neighbors.     : [9, 16, 76, 0, 10, 31, 91, 106, 67, 32, 33, 70, 72, 46, 19, 89, 68, 14, 51, 93]
# --- 0.49 minutes passed ---------
# 0
# 10
# 46
# 21
# 91
# 83
# 26
# 12
# 79
# 89
# 31
# 68
# 32
# 16
# 81
# 75
# 76
# 70
# 9
# 54
# ---------------------------------
# Similarity index       : 10
# Master Image file name : 33_1
# Nearest Neighbors.     : [0, 10, 46, 21, 91, 83, 26, 12, 79, 89, 31, 68, 32, 16, 81, 75, 76, 70, 9, 54]
# --- 0.49 minutes passed ---------
# 11
# 92
# 27
# 50
# 75
# 83
# 88
# 101
# 54
# 3
# 16
# 7
# 4
# 94
# 30
# 32
# 33
# 58
# 23
# 69
# ---------------------------------
# Similarity index       : 11
# Master Image file name : 50_0
# Nearest Neighbors.     : [11, 92, 27, 50, 75, 83, 88, 101, 54, 3, 16, 7, 4, 94, 30, 32, 33, 58, 23, 69]
# --- 0.49 minutes passed ---------
# 12
# 46
# 97
# 21
# 0
# 10
# 70
# 26
# 91
# 31
# 105
# 79
# 89
# 83
# 64
# 93
# 42
# 48
# 68
# 9
# ---------------------------------
# Similarity index       : 12
# Master Image file name : 43_2
# Nearest Neighbors.     : [12, 46, 97, 21, 0, 10, 70, 26, 91, 31, 105, 79, 89, 83, 64, 93, 42, 48, 68, 9]
# --- 0.49 minutes passed ---------
# 13
# 86
# 22
# 67
# 56
# 102
# 85
# 14
# 6
# 36
# 90
# 69
# 101
# 96
# 94
# 52
# 44
# 30
# 24
# 66
# ---------------------------------
# Similarity index       : 13
# Master Image file name : 9_0
# Nearest Neighbors.     : [13, 86, 22, 67, 56, 102, 85, 14, 6, 36, 90, 69, 101, 96, 94, 52, 44, 30, 24, 66]
# --- 0.49 minutes passed ---------
# 14
# 86
# 33
# 65
# 22
# 20
# 41
# 72
# 2
# 35
# 16
# 88
# 94
# 36
# 102
# 51
# 15
# 104
# 101
# 54
# ---------------------------------
# Similarity index       : 14
# Master Image file name : 26_1
# Nearest Neighbors.     : [14, 86, 33, 65, 22, 20, 41, 72, 2, 35, 16, 88, 94, 36, 102, 51, 15, 104, 101, 54]
# --- 0.49 minutes passed ---------
# 15
# 102
# 24
# 106
# 37
# 96
# 107
# 36
# 33
# 67
# 39
# 20
# 90
# 35
# 3
# 17
# 68
# 101
# 30
# 8
# ---------------------------------
# Similarity index       : 15
# Master Image file name : 38_0
# Nearest Neighbors.     : [15, 102, 24, 106, 37, 96, 107, 36, 33, 67, 39, 20, 90, 35, 3, 17, 68, 101, 30, 8]
# --- 0.49 minutes passed ---------
# 16
# 88
# 32
# 54
# 83
# 31
# 92
# 37
# 86
# 76
# 65
# 91
# 66
# 3
# 102
# 106
# 107
# 78
# 14
# 75
# ---------------------------------
# Similarity index       : 16
# Master Image file name : 73_1
# Nearest Neighbors.     : [16, 88, 32, 54, 83, 31, 92, 37, 86, 76, 65, 91, 66, 3, 102, 106, 107, 78, 14, 75]
# --- 0.49 minutes passed ---------
# 17
# 107
# 95
# 104
# 23
# 106
# 74
# 37
# 30
# 28
# 15
# 57
# 39
# 78
# 24
# 96
# 71
# 102
# 65
# 101
# ---------------------------------
# Similarity index       : 17
# Master Image file name : 48_0
# Nearest Neighbors.     : [17, 107, 95, 104, 23, 106, 74, 37, 30, 28, 15, 57, 39, 78, 24, 96, 71, 102, 65, 101]
# --- 0.49 minutes passed ---------
# 18
# 25
# 1
# 80
# 42
# 64
# 58
# 55
# 49
# 43
# 4
# 81
# 5
# 98
# 79
# 83
# 26
# 37
# 88
# 89
# ---------------------------------
# Similarity index       : 18
# Master Image file name : 57_1
# Nearest Neighbors.     : [18, 25, 1, 80, 42, 64, 58, 55, 49, 43, 4, 81, 5, 98, 79, 83, 26, 37, 88, 89]
# --- 0.49 minutes passed ---------
# 19
# 2
# 8
# 78
# 20
# 51
# 28
# 23
# 14
# 35
# 22
# 93
# 24
# 95
# 41
# 33
# 109
# 36
# 65
# 106
# ---------------------------------
# Similarity index       : 19
# Master Image file name : 25_2
# Nearest Neighbors.     : [19, 2, 8, 78, 20, 51, 28, 23, 14, 35, 22, 93, 24, 95, 41, 33, 109, 36, 65, 106]
# --- 0.49 minutes passed ---------
# 20
# 8
# 3
# 36
# 52
# 35
# 72
# 33
# 69
# 51
# 96
# 15
# 2
# 67
# 22
# 14
# 86
# 109
# 19
# 41
# ---------------------------------
# Similarity index       : 20
# Master Image file name : 40_0
# Nearest Neighbors.     : [20, 8, 3, 36, 52, 35, 72, 33, 69, 51, 96, 15, 2, 67, 22, 14, 86, 109, 19, 41]
# --- 0.49 minutes passed ---------
# 21
# 46
# 12
# 0
# 10
# 26
# 31
# 83
# 54
# 79
# 91
# 75
# 89
# 97
# 16
# 32
# 58
# 105
# 81
# 88
# ---------------------------------
# Similarity index       : 21
# Master Image file name : 39_0
# Nearest Neighbors.     : [21, 46, 12, 0, 10, 26, 31, 83, 54, 79, 91, 75, 89, 97, 16, 32, 58, 105, 81, 88]
# --- 0.49 minutes passed ---------
# 22
# 67
# 36
# 8
# 33
# 102
# 86
# 20
# 35
# 3
# 14
# 6
# 24
# 69
# 72
# 52
# 101
# 94
# 106
# 85
# ---------------------------------
# Similarity index       : 22
# Master Image file name : 52_0
# Nearest Neighbors.     : [22, 67, 36, 8, 33, 102, 86, 20, 35, 3, 14, 6, 24, 69, 72, 52, 101, 94, 106, 85]
# --- 0.49 minutes passed ---------
# 23
# 74
# 17
# 36
# 107
# 37
# 65
# 30
# 101
# 106
# 15
# 95
# 35
# 16
# 96
# 88
# 33
# 24
# 102
# 39
# ---------------------------------
# Similarity index       : 23
# Master Image file name : 53_0
# Nearest Neighbors.     : [23, 74, 17, 36, 107, 37, 65, 30, 101, 106, 15, 95, 35, 16, 96, 88, 33, 24, 102, 39]
# --- 0.49 minutes passed ---------
# 24
# 106
# 15
# 102
# 39
# 36
# 6
# 35
# 30
# 33
# 78
# 107
# 74
# 3
# 68
# 37
# 96
# 22
# 101
# 67
# ---------------------------------
# Similarity index       : 24
# Master Image file name : 34_0
# Nearest Neighbors.     : [24, 106, 15, 102, 39, 36, 6, 35, 30, 33, 78, 107, 74, 3, 68, 37, 96, 22, 101, 67]
# --- 0.49 minutes passed ---------
# 25
# 18
# 1
# 80
# 55
# 64
# 49
# 58
# 42
# 5
# 43
# 81
# 4
# 98
# 79
# 88
# 26
# 103
# 83
# 77
# ---------------------------------
# Similarity index       : 25
# Master Image file name : 57_0
# Nearest Neighbors.     : [25, 18, 1, 80, 55, 64, 49, 58, 42, 5, 43, 81, 4, 98, 79, 88, 26, 103, 83, 77]
# --- 0.49 minutes passed ---------
# 26
# 79
# 83
# 91
# 21
# 0
# 10
# 46
# 12
# 70
# 99
# 31
# 81
# 64
# 75
# 58
# 74
# 89
# 88
# 62
# ---------------------------------
# Similarity index       : 26
# Master Image file name : 43_0
# Nearest Neighbors.     : [26, 79, 83, 91, 21, 0, 10, 46, 12, 70, 99, 31, 81, 64, 75, 58, 74, 89, 88, 62]
# --- 0.49 minutes passed ---------
# 27
# 92
# 7
# 101
# 54
# 11
# 53
# 50
# 94
# 84
# 75
# 88
# 4
# 30
# 83
# 47
# 3
# 44
# 65
# 16
# ---------------------------------
# Similarity index       : 27
# Master Image file name : 70_0
# Nearest Neighbors.     : [27, 92, 7, 101, 54, 11, 53, 50, 94, 84, 75, 88, 4, 30, 83, 47, 3, 44, 65, 16]
# --- 0.49 minutes passed ---------
# 28
# 95
# 108
# 17
# 78
# 24
# 19
# 2
# 74
# 107
# 39
# 14
# 23
# 73
# 104
# 103
# 37
# 35
# 100
# 36
# ---------------------------------
# Similarity index       : 28
# Master Image file name : 20_0
# Nearest Neighbors.     : [28, 95, 108, 17, 78, 24, 19, 2, 74, 107, 39, 14, 23, 73, 104, 103, 37, 35, 100, 36]
# --- 0.49 minutes passed ---------
# 29
# 78
# 24
# 74
# 107
# 28
# 103
# 104
# 17
# 38
# 79
# 108
# 91
# 15
# 68
# 23
# 93
# 39
# 37
# 95
# ---------------------------------
# Similarity index       : 29
# Master Image file name : 5_0
# Nearest Neighbors.     : [29, 78, 24, 74, 107, 28, 103, 104, 17, 38, 79, 108, 91, 15, 68, 23, 93, 39, 37, 95]
# --- 0.50 minutes passed ---------
# 30
# 106
# 101
# 39
# 3
# 102
# 36
# 90
# 24
# 35
# 67
# 74
# 107
# 104
# 33
# 23
# 47
# 37
# 17
# 92
# ---------------------------------
# Similarity index       : 30
# Master Image file name : 11_0
# Nearest Neighbors.     : [30, 106, 101, 39, 3, 102, 36, 90, 24, 35, 67, 74, 107, 104, 33, 23, 47, 37, 17, 92]
# --- 0.50 minutes passed ---------
# 31
# 32
# 91
# 16
# 46
# 75
# 83
# 21
# 70
# 0
# 10
# 26
# 79
# 45
# 9
# 62
# 64
# 68
# 88
# 12
# ---------------------------------
# Similarity index       : 31
# Master Image file name : 62_1
# Nearest Neighbors.     : [31, 32, 91, 16, 46, 75, 83, 21, 70, 0, 10, 26, 79, 45, 9, 62, 64, 68, 88, 12]
# --- 0.50 minutes passed ---------
# 32
# 16
# 31
# 88
# 54
# 83
# 37
# 76
# 51
# 0
# 10
# 3
# 78
# 91
# 107
# 92
# 68
# 20
# 35
# 46
# ---------------------------------
# Similarity index       : 32
# Master Image file name : 7_0
# Nearest Neighbors.     : [32, 16, 31, 88, 54, 83, 37, 76, 51, 0, 10, 3, 78, 91, 107, 92, 68, 20, 35, 46]
# --- 0.50 minutes passed ---------
# 33
# 35
# 101
# 72
# 36
# 106
# 76
# 22
# 3
# 8
# 102
# 96
# 20
# 15
# 24
# 14
# 6
# 30
# 94
# 88
# ---------------------------------
# Similarity index       : 33
# Master Image file name : 44_0
# Nearest Neighbors.     : [33, 35, 101, 72, 36, 106, 76, 22, 3, 8, 102, 96, 20, 15, 24, 14, 6, 30, 94, 88]
# --- 0.50 minutes passed ---------
# 34
# 40
# 87
# 77
# 0
# 10
# 68
# 93
# 91
# 49
# 48
# 78
# 70
# 98
# 38
# 31
# 64
# 19
# 16
# 89
# ---------------------------------
# Similarity index       : 34
# Master Image file name : 26_2
# Nearest Neighbors.     : [34, 40, 87, 77, 0, 10, 68, 93, 91, 49, 48, 78, 70, 98, 38, 31, 64, 19, 16, 89]
# --- 0.50 minutes passed ---------
# 35
# 36
# 33
# 69
# 3
# 20
# 24
# 51
# 30
# 101
# 41
# 106
# 102
# 52
# 22
# 8
# 15
# 39
# 85
# 2
# ---------------------------------
# Similarity index       : 35
# Master Image file name : 47_0
# Nearest Neighbors.     : [35, 36, 33, 69, 3, 20, 24, 51, 30, 101, 41, 106, 102, 52, 22, 8, 15, 39, 85, 2]
# --- 0.50 minutes passed ---------
# 36
# 35
# 96
# 102
# 33
# 22
# 30
# 24
# 20
# 69
# 15
# 3
# 67
# 23
# 106
# 101
# 85
# 6
# 39
# 8
# ---------------------------------
# Similarity index       : 36
# Master Image file name : 41_0
# Nearest Neighbors.     : [36, 35, 96, 102, 33, 22, 30, 24, 20, 69, 15, 3, 67, 23, 106, 101, 85, 6, 39, 8]
# --- 0.50 minutes passed ---------
# 37
# 107
# 3
# 15
# 104
# 39
# 78
# 16
# 83
# 88
# 74
# 23
# 32
# 54
# 92
# 30
# 90
# 101
# 17
# 72
# ---------------------------------
# Similarity index       : 37
# Master Image file name : 8_0
# Nearest Neighbors.     : [37, 107, 3, 15, 104, 39, 78, 16, 83, 88, 74, 23, 32, 54, 92, 30, 90, 101, 17, 72]
# --- 0.50 minutes passed ---------
# 38
# 91
# 23
# 48
# 107
# 74
# 68
# 106
# 24
# 78
# 93
# 79
# 102
# 96
# 88
# 17
# 57
# 49
# 15
# 98
# ---------------------------------
# Similarity index       : 38
# Master Image file name : 59_0
# Nearest Neighbors.     : [38, 91, 23, 48, 107, 74, 68, 106, 24, 78, 93, 79, 102, 96, 88, 17, 57, 49, 15, 98]
# --- 0.50 minutes passed ---------
# 39
# 107
# 104
# 106
# 24
# 101
# 30
# 37
# 74
# 67
# 3
# 15
# 90
# 36
# 102
# 78
# 35
# 72
# 61
# 51
# ---------------------------------
# Similarity index       : 39
# Master Image file name : 30_0
# Nearest Neighbors.     : [39, 107, 104, 106, 24, 101, 30, 37, 74, 67, 3, 15, 90, 36, 102, 78, 35, 72, 61, 51]
# --- 0.50 minutes passed ---------
# 40
# 34
# 87
# 77
# 93
# 0
# 10
# 68
# 91
# 19
# 70
# 89
# 9
# 78
# 31
# 46
# 2
# 12
# 21
# 16
# ---------------------------------
# Similarity index       : 40
# Master Image file name : 26_0
# Nearest Neighbors.     : [40, 34, 87, 77, 93, 0, 10, 68, 91, 19, 70, 89, 9, 78, 31, 46, 2, 12, 21, 16]
# --- 0.50 minutes passed ---------
# 41
# 51
# 65
# 69
# 88
# 35
# 2
# 66
# 86
# 14
# 20
# 33
# 3
# 104
# 101
# 52
# 39
# 36
# 107
# 109
# ---------------------------------
# Similarity index       : 41
# Master Image file name : 15_0
# Nearest Neighbors.     : [41, 51, 65, 69, 88, 35, 2, 66, 86, 14, 20, 33, 3, 104, 101, 52, 39, 36, 107, 109]
# --- 0.50 minutes passed ---------
# 42
# 64
# 1
# 58
# 80
# 83
# 49
# 77
# 4
# 91
# 0
# 10
# 18
# 75
# 55
# 79
# 92
# 81
# 26
# 70
# ---------------------------------
# Similarity index       : 42
# Master Image file name : 13_1
# Nearest Neighbors.     : [42, 64, 1, 58, 80, 83, 49, 77, 4, 91, 0, 10, 18, 75, 55, 79, 92, 81, 26, 70]
# --- 0.50 minutes passed ---------
# 43
# 4
# 83
# 37
# 79
# 58
# 88
# 64
# 42
# 80
# 92
# 81
# 101
# 54
# 49
# 32
# 76
# 16
# 55
# 26
# ---------------------------------
# Similarity index       : 43
# Master Image file name : 58_0
# Nearest Neighbors.     : [43, 4, 83, 37, 79, 58, 88, 64, 42, 80, 92, 81, 101, 54, 49, 32, 76, 16, 55, 26]
# --- 0.50 minutes passed ---------
# 44
# 56
# 7
# 84
# 41
# 86
# 92
# 88
# 54
# 27
# 69
# 16
# 13
# 65
# 6
# 52
# 101
# 76
# 14
# 33
# ---------------------------------
# Similarity index       : 44
# Master Image file name : 35_0
# Nearest Neighbors.     : [44, 56, 7, 84, 41, 86, 92, 88, 54, 27, 69, 16, 13, 65, 6, 52, 101, 76, 14, 33]
# --- 0.50 minutes passed ---------
# 45
# 31
# 26
# 79
# 91
# 21
# 68
# 46
# 32
# 0
# 10
# 16
# 70
# 62
# 83
# 37
# 76
# 9
# 59
# 81
# ---------------------------------
# Similarity index       : 45
# Master Image file name : 26_3
# Nearest Neighbors.     : [45, 31, 26, 79, 91, 21, 68, 46, 32, 0, 10, 16, 70, 62, 83, 37, 76, 9, 59, 81]
# --- 0.50 minutes passed ---------
# 46
# 21
# 12
# 0
# 10
# 31
# 83
# 26
# 54
# 91
# 16
# 75
# 97
# 79
# 32
# 88
# 89
# 105
# 58
# 74
# ---------------------------------
# Similarity index       : 46
# Master Image file name : 39_1
# Nearest Neighbors.     : [46, 21, 12, 0, 10, 31, 83, 26, 54, 91, 16, 75, 97, 79, 32, 88, 89, 105, 58, 74]
# --- 0.50 minutes passed ---------
# 47
# 101
# 30
# 36
# 33
# 72
# 106
# 90
# 7
# 3
# 35
# 92
# 67
# 102
# 8
# 15
# 76
# 20
# 6
# 23
# ---------------------------------
# Similarity index       : 47
# Master Image file name : 4_0
# Nearest Neighbors.     : [47, 101, 30, 36, 33, 72, 106, 90, 7, 3, 35, 92, 67, 102, 8, 15, 76, 20, 6, 23]
# --- 0.50 minutes passed ---------
# 48
# 68
# 38
# 91
# 0
# 10
# 93
# 79
# 34
# 31
# 24
# 12
# 26
# 64
# 46
# 77
# 81
# 15
# 102
# 21
# ---------------------------------
# Similarity index       : 48
# Master Image file name : 71_0
# Nearest Neighbors.     : [48, 68, 38, 91, 0, 10, 93, 79, 34, 31, 24, 12, 26, 64, 46, 77, 81, 15, 102, 21]
# --- 0.50 minutes passed ---------
# 49
# 64
# 1
# 58
# 42
# 77
# 80
# 5
# 98
# 4
# 81
# 0
# 10
# 23
# 37
# 93
# 88
# 55
# 38
# 74
# ---------------------------------
# Similarity index       : 49
# Master Image file name : 13_0
# Nearest Neighbors.     : [49, 64, 1, 58, 42, 77, 80, 5, 98, 4, 81, 0, 10, 23, 37, 93, 88, 55, 38, 74]
# --- 0.50 minutes passed ---------
# 50
# 92
# 7
# 30
# 27
# 54
# 101
# 83
# 11
# 53
# 94
# 3
# 88
# 86
# 90
# 16
# 84
# 102
# 96
# 47
# ---------------------------------
# Similarity index       : 50
# Master Image file name : 12_0
# Nearest Neighbors.     : [50, 92, 7, 30, 27, 54, 101, 83, 11, 53, 94, 3, 88, 86, 90, 16, 84, 102, 96, 47]
# --- 0.50 minutes passed ---------
# 51
# 41
# 35
# 104
# 2
# 20
# 88
# 3
# 66
# 107
# 65
# 32
# 19
# 39
# 36
# 74
# 69
# 78
# 37
# 14
# ---------------------------------
# Similarity index       : 51
# Master Image file name : 19_1
# Nearest Neighbors.     : [51, 41, 35, 104, 2, 20, 88, 3, 66, 107, 65, 32, 19, 39, 36, 74, 69, 78, 37, 14]
# --- 0.50 minutes passed ---------
# 52
# 69
# 20
# 96
# 56
# 3
# 35
# 7
# 36
# 85
# 33
# 94
# 88
# 22
# 41
# 106
# 101
# 90
# 8
# 102
# ---------------------------------
# Similarity index       : 52
# Master Image file name : 16_0
# Nearest Neighbors.     : [52, 69, 20, 96, 56, 3, 35, 7, 36, 85, 33, 94, 88, 22, 41, 106, 101, 90, 8, 102]
# --- 0.50 minutes passed ---------
# 53
# 54
# 92
# 37
# 83
# 101
# 30
# 3
# 90
# 104
# 76
# 88
# 72
# 74
# 107
# 39
# 75
# 16
# 67
# 96
# ---------------------------------
# Similarity index       : 53
# Master Image file name : 18_0
# Nearest Neighbors.     : [53, 54, 92, 37, 83, 101, 30, 3, 90, 104, 76, 88, 72, 74, 107, 39, 75, 16, 67, 96]
# --- 0.50 minutes passed ---------
# 54
# 92
# 16
# 88
# 83
# 101
# 32
# 76
# 74
# 37
# 75
# 7
# 53
# 33
# 94
# 72
# 46
# 30
# 65
# 21
# ---------------------------------
# Similarity index       : 54
# Master Image file name : 73_0
# Nearest Neighbors.     : [54, 92, 16, 88, 83, 101, 32, 76, 74, 37, 75, 7, 53, 33, 94, 72, 46, 30, 65, 21]
# --- 0.50 minutes passed ---------
# 55
# 64
# 58
# 42
# 18
# 79
# 26
# 1
# 25
# 49
# 83
# 80
# 81
# 43
# 74
# 98
# 91
# 5
# 88
# 31
# ---------------------------------
# Similarity index       : 55
# Master Image file name : 6_0
# Nearest Neighbors.     : [55, 64, 58, 42, 18, 79, 26, 1, 25, 49, 83, 80, 81, 43, 74, 98, 91, 5, 88, 31]
# --- 0.50 minutes passed ---------
# 56
# 52
# 6
# 85
# 69
# 96
# 36
# 33
# 94
# 86
# 22
# 71
# 101
# 24
# 7
# 3
# 35
# 65
# 13
# 15
# ---------------------------------
# Similarity index       : 56
# Master Image file name : 77_0
# Nearest Neighbors.     : [56, 52, 6, 85, 69, 96, 36, 33, 94, 86, 22, 71, 101, 24, 7, 3, 35, 65, 13, 15]
# --- 0.50 minutes passed ---------
# 57
# 95
# 107
# 104
# 17
# 61
# 37
# 84
# 23
# 74
# 88
# 60
# 65
# 96
# 30
# 78
# 39
# 38
# 94
# 16
# ---------------------------------
# Similarity index       : 57
# Master Image file name : 17_0
# Nearest Neighbors.     : [57, 95, 107, 104, 17, 61, 37, 84, 23, 74, 88, 60, 65, 96, 30, 78, 39, 38, 94, 16]
# --- 0.50 minutes passed ---------
# 58
# 64
# 83
# 42
# 75
# 49
# 4
# 37
# 88
# 1
# 79
# 55
# 26
# 80
# 81
# 54
# 21
# 46
# 18
# 0
# ---------------------------------
# Similarity index       : 58
# Master Image file name : 76_0
# Nearest Neighbors.     : [58, 64, 83, 42, 75, 49, 4, 37, 88, 1, 79, 55, 26, 80, 81, 54, 21, 46, 18, 0]
# --- 0.50 minutes passed ---------
# 59
# 99
# 88
# 79
# 62
# 83
# 54
# 32
# 26
# 104
# 37
# 15
# 16
# 14
# 71
# 81
# 107
# 76
# 65
# 45
# ---------------------------------
# Similarity index       : 59
# Master Image file name : 64_2
# Nearest Neighbors.     : [59, 99, 88, 79, 62, 83, 54, 32, 26, 104, 37, 15, 16, 14, 71, 81, 107, 76, 65, 45]
# --- 0.50 minutes passed ---------
# 60
# 104
# 74
# 107
# 61
# 100
# 39
# 37
# 65
# 95
# 84
# 88
# 101
# 41
# 51
# 78
# 73
# 30
# 4
# 92
# ---------------------------------
# Similarity index       : 60
# Master Image file name : 1_0
# Nearest Neighbors.     : [60, 104, 74, 107, 61, 100, 39, 37, 65, 95, 84, 88, 101, 41, 51, 78, 73, 30, 4, 92]
# --- 0.50 minutes passed ---------
# 61
# 104
# 60
# 107
# 39
# 95
# 100
# 51
# 78
# 41
# 57
# 65
# 74
# 37
# 17
# 71
# 24
# 88
# 30
# 84
# ---------------------------------
# Similarity index       : 61
# Master Image file name : 55_0
# Nearest Neighbors.     : [61, 104, 60, 107, 39, 95, 100, 51, 78, 41, 57, 65, 74, 37, 17, 71, 24, 88, 30, 84]
# --- 0.50 minutes passed ---------
# 62
# 31
# 79
# 15
# 59
# 26
# 33
# 0
# 10
# 37
# 20
# 83
# 88
# 2
# 32
# 54
# 68
# 8
# 3
# 76
# ---------------------------------
# Similarity index       : 62
# Master Image file name : 54_0
# Nearest Neighbors.     : [62, 31, 79, 15, 59, 26, 33, 0, 10, 37, 20, 83, 88, 2, 32, 54, 68, 8, 3, 76]
# --- 0.50 minutes passed ---------
# 63
# 68
# 24
# 19
# 0
# 10
# 14
# 93
# 89
# 36
# 15
# 28
# 9
# 6
# 106
# 74
# 78
# 108
# 33
# 29
# ---------------------------------
# Similarity index       : 63
# Master Image file name : 42_1
# Nearest Neighbors.     : [63, 68, 24, 19, 0, 10, 14, 93, 89, 36, 15, 28, 9, 6, 106, 74, 78, 108, 33, 29]
# --- 0.50 minutes passed ---------
# 64
# 42
# 58
# 49
# 55
# 79
# 83
# 26
# 91
# 81
# 1
# 31
# 80
# 0
# 10
# 5
# 32
# 88
# 70
# 75
# ---------------------------------
# Similarity index       : 64
# Master Image file name : 13_3
# Nearest Neighbors.     : [64, 42, 58, 49, 55, 79, 83, 26, 91, 81, 1, 31, 80, 0, 10, 5, 32, 88, 70, 75]
# --- 0.50 minutes passed ---------
# 65
# 88
# 41
# 71
# 86
# 74
# 16
# 14
# 23
# 51
# 2
# 95
# 104
# 54
# 101
# 73
# 33
# 66
# 60
# 94
# ---------------------------------
# Similarity index       : 65
# Master Image file name : 64_1
# Nearest Neighbors.     : [65, 88, 41, 71, 86, 74, 16, 14, 23, 51, 2, 95, 104, 54, 101, 73, 33, 66, 60, 94]
# --- 0.50 minutes passed ---------
# 66
# 88
# 51
# 41
# 16
# 86
# 20
# 36
# 96
# 65
# 69
# 102
# 94
# 14
# 35
# 15
# 23
# 3
# 32
# 24
# ---------------------------------
# Similarity index       : 66
# Master Image file name : 42_0
# Nearest Neighbors.     : [66, 88, 51, 41, 16, 86, 20, 36, 96, 65, 69, 102, 94, 14, 35, 15, 23, 3, 32, 24]
# --- 0.50 minutes passed ---------
# 67
# 102
# 106
# 22
# 90
# 3
# 101
# 30
# 39
# 36
# 15
# 86
# 72
# 20
# 33
# 37
# 24
# 35
# 8
# 96
# ---------------------------------
# Similarity index       : 67
# Master Image file name : 51_0
# Nearest Neighbors.     : [67, 102, 106, 22, 90, 3, 101, 30, 39, 36, 15, 86, 72, 20, 33, 37, 24, 35, 8, 96]
# --- 0.50 minutes passed ---------
# 68
# 91
# 24
# 78
# 15
# 0
# 10
# 93
# 35
# 107
# 51
# 106
# 48
# 37
# 74
# 32
# 31
# 16
# 38
# 70
# ---------------------------------
# Similarity index       : 68
# Master Image file name : 3_0
# Nearest Neighbors.     : [68, 91, 24, 78, 15, 0, 10, 93, 35, 107, 51, 106, 48, 37, 74, 32, 31, 16, 38, 70]
# --- 0.50 minutes passed ---------
# 69
# 52
# 35
# 41
# 36
# 20
# 85
# 33
# 96
# 56
# 3
# 22
# 94
# 51
# 24
# 102
# 101
# 6
# 66
# 8
# ---------------------------------
# Similarity index       : 69
# Master Image file name : 31_0
# Nearest Neighbors.     : [69, 52, 35, 41, 36, 20, 85, 33, 96, 56, 3, 22, 94, 51, 24, 102, 101, 6, 66, 8]
# --- 0.51 minutes passed ---------
# 70
# 91
# 31
# 12
# 26
# 93
# 0
# 10
# 79
# 68
# 64
# 83
# 9
# 87
# 32
# 21
# 46
# 42
# 74
# 78
# ---------------------------------
# Similarity index       : 70
# Master Image file name : 22_0
# Nearest Neighbors.     : [70, 91, 31, 12, 26, 93, 0, 10, 79, 68, 64, 83, 9, 87, 32, 21, 46, 42, 74, 78]
# --- 0.51 minutes passed ---------
# 71
# 65
# 33
# 101
# 74
# 17
# 2
# 104
# 14
# 88
# 95
# 108
# 41
# 96
# 94
# 35
# 73
# 56
# 69
# 51
# ---------------------------------
# Similarity index       : 71
# Master Image file name : 80_0
# Nearest Neighbors.     : [71, 65, 33, 101, 74, 17, 2, 104, 14, 88, 95, 108, 41, 96, 94, 35, 73, 56, 69, 51]
# --- 0.51 minutes passed ---------
# 72
# 33
# 90
# 20
# 101
# 67
# 92
# 3
# 37
# 36
# 39
# 106
# 14
# 54
# 102
# 22
# 35
# 76
# 30
# 24
# ---------------------------------
# Similarity index       : 72
# Master Image file name : 36_0
# Nearest Neighbors.     : [72, 33, 90, 20, 101, 67, 92, 3, 37, 36, 39, 106, 14, 54, 102, 22, 35, 76, 30, 24]
# --- 0.51 minutes passed ---------
# 73
# 74
# 65
# 95
# 104
# 79
# 107
# 60
# 71
# 28
# 88
# 2
# 78
# 26
# 41
# 51
# 100
# 101
# 23
# 39
# ---------------------------------
# Similarity index       : 73
# Master Image file name : 37_0
# Nearest Neighbors.     : [73, 74, 65, 95, 104, 79, 107, 60, 71, 28, 88, 2, 78, 26, 41, 51, 100, 101, 23, 39]
# --- 0.51 minutes passed ---------
# 74
# 104
# 107
# 60
# 23
# 73
# 78
# 39
# 65
# 101
# 30
# 54
# 37
# 24
# 17
# 88
# 91
# 106
# 83
# 76
# ---------------------------------
# Similarity index       : 74
# Master Image file name : 0_0
# Nearest Neighbors.     : [74, 104, 107, 60, 23, 73, 78, 39, 65, 101, 30, 54, 37, 24, 17, 88, 91, 106, 83, 76]
# --- 0.51 minutes passed ---------
# 75
# 83
# 31
# 54
# 16
# 58
# 0
# 10
# 92
# 88
# 46
# 21
# 79
# 26
# 91
# 32
# 101
# 64
# 76
# 42
# ---------------------------------
# Similarity index       : 75
# Master Image file name : 62_0
# Nearest Neighbors.     : [75, 83, 31, 54, 16, 58, 0, 10, 92, 88, 46, 21, 79, 26, 91, 32, 101, 64, 76, 42]
# --- 0.51 minutes passed ---------
# 76
# 88
# 33
# 106
# 16
# 54
# 101
# 32
# 74
# 83
# 39
# 72
# 3
# 0
# 10
# 30
# 35
# 9
# 51
# 90
# ---------------------------------
# Similarity index       : 76
# Master Image file name : 2_0
# Nearest Neighbors.     : [76, 88, 33, 106, 16, 54, 101, 32, 74, 83, 39, 72, 3, 0, 10, 30, 35, 9, 51, 90]
# --- 0.51 minutes passed ---------
# 77
# 34
# 40
# 93
# 87
# 49
# 42
# 0
# 10
# 68
# 91
# 80
# 89
# 98
# 38
# 15
# 24
# 83
# 64
# 23
# ---------------------------------
# Similarity index       : 77
# Master Image file name : 46_0
# Nearest Neighbors.     : [77, 34, 40, 93, 87, 49, 42, 0, 10, 68, 91, 80, 89, 98, 38, 15, 24, 83, 64, 23]
# --- 0.51 minutes passed ---------
# 78
# 107
# 74
# 37
# 104
# 24
# 39
# 68
# 93
# 19
# 28
# 2
# 16
# 17
# 95
# 32
# 51
# 102
# 61
# 23
# ---------------------------------
# Similarity index       : 78
# Master Image file name : 28_0
# Nearest Neighbors.     : [78, 107, 74, 37, 104, 24, 39, 68, 93, 19, 28, 2, 16, 17, 95, 32, 51, 102, 61, 23]
# --- 0.51 minutes passed ---------
# 79
# 26
# 83
# 91
# 99
# 0
# 10
# 81
# 64
# 21
# 74
# 31
# 75
# 88
# 46
# 70
# 73
# 59
# 54
# 62
# ---------------------------------
# Similarity index       : 79
# Master Image file name : 43_1
# Nearest Neighbors.     : [79, 26, 83, 91, 99, 0, 10, 81, 64, 21, 74, 31, 75, 88, 46, 70, 73, 59, 54, 62]
# --- 0.51 minutes passed ---------
# 80
# 18
# 42
# 1
# 88
# 64
# 49
# 16
# 58
# 25
# 92
# 4
# 81
# 83
# 77
# 76
# 54
# 32
# 37
# 43
# ---------------------------------
# Similarity index       : 80
# Master Image file name : 57_2
# Nearest Neighbors.     : [80, 18, 42, 1, 88, 64, 49, 16, 58, 25, 92, 4, 81, 83, 77, 76, 54, 32, 37, 43]
# --- 0.51 minutes passed ---------
# 81
# 79
# 0
# 10
# 26
# 83
# 99
# 64
# 58
# 88
# 75
# 21
# 89
# 15
# 42
# 49
# 37
# 80
# 54
# 46
# ---------------------------------
# Similarity index       : 81
# Master Image file name : 97_1
# Nearest Neighbors.     : [81, 79, 0, 10, 26, 83, 99, 64, 58, 88, 75, 21, 89, 15, 42, 49, 37, 80, 54, 46]
# --- 0.51 minutes passed ---------
# 82
# 24
# 102
# 15
# 68
# 96
# 66
# 38
# 6
# 36
# 85
# 95
# 69
# 106
# 78
# 8
# 86
# 16
# 98
# 107
# ---------------------------------
# Similarity index       : 82
# Master Image file name : 91_0
# Nearest Neighbors.     : [82, 24, 102, 15, 68, 96, 66, 38, 6, 36, 85, 95, 69, 106, 78, 8, 86, 16, 98, 107]
# --- 0.51 minutes passed ---------
# 83
# 75
# 16
# 54
# 88
# 79
# 91
# 32
# 26
# 37
# 0
# 10
# 58
# 92
# 31
# 42
# 74
# 21
# 46
# 76
# ---------------------------------
# Similarity index       : 83
# Master Image file name : 25_3
# Nearest Neighbors.     : [83, 75, 16, 54, 88, 79, 91, 32, 26, 37, 0, 10, 58, 92, 31, 42, 74, 21, 46, 76]
# --- 0.51 minutes passed ---------
# 84
# 101
# 74
# 95
# 104
# 30
# 57
# 60
# 7
# 65
# 88
# 23
# 92
# 54
# 86
# 17
# 41
# 107
# 69
# 37
# ---------------------------------
# Similarity index       : 84
# Master Image file name : 99_0
# Nearest Neighbors.     : [84, 101, 74, 95, 104, 30, 57, 60, 7, 65, 88, 23, 92, 54, 86, 17, 41, 107, 69, 37]
# --- 0.51 minutes passed ---------
# 85
# 6
# 69
# 36
# 96
# 56
# 35
# 52
# 24
# 22
# 20
# 33
# 3
# 37
# 102
# 106
# 15
# 8
# 107
# 72
# ---------------------------------
# Similarity index       : 85
# Master Image file name : 89_0
# Nearest Neighbors.     : [85, 6, 69, 36, 96, 56, 35, 52, 24, 22, 20, 33, 3, 37, 102, 106, 15, 8, 107, 72]
# --- 0.51 minutes passed ---------
# 86
# 14
# 102
# 65
# 16
# 67
# 22
# 94
# 88
# 20
# 41
# 101
# 106
# 66
# 33
# 13
# 7
# 6
# 96
# 54
# ---------------------------------
# Similarity index       : 86
# Master Image file name : 76_1
# Nearest Neighbors.     : [86, 14, 102, 65, 16, 67, 22, 94, 88, 20, 41, 101, 106, 66, 33, 13, 7, 6, 96, 54]
# --- 0.51 minutes passed ---------
# 87
# 40
# 34
# 93
# 77
# 0
# 10
# 70
# 91
# 78
# 68
# 19
# 49
# 12
# 31
# 9
# 89
# 48
# 38
# 98
# ---------------------------------
# Similarity index       : 87
# Master Image file name : 87_0
# Nearest Neighbors.     : [87, 40, 34, 93, 77, 0, 10, 70, 91, 78, 68, 19, 49, 12, 31, 9, 89, 48, 38, 98]
# --- 0.51 minutes passed ---------
# 88
# 16
# 54
# 76
# 83
# 65
# 32
# 92
# 41
# 101
# 66
# 37
# 51
# 104
# 33
# 3
# 107
# 74
# 4
# 86
# ---------------------------------
# Similarity index       : 88
# Master Image file name : 73_2
# Nearest Neighbors.     : [88, 16, 54, 76, 83, 65, 32, 92, 41, 101, 66, 37, 51, 104, 33, 3, 107, 74, 4, 86]
# --- 0.51 minutes passed ---------
# 89
# 91
# 0
# 10
# 83
# 93
# 21
# 79
# 26
# 46
# 74
# 76
# 81
# 9
# 12
# 31
# 77
# 42
# 88
# 70
# ---------------------------------
# Similarity index       : 89
# Master Image file name : 81_0
# Nearest Neighbors.     : [89, 91, 0, 10, 83, 93, 21, 79, 26, 46, 74, 76, 81, 9, 12, 31, 77, 42, 88, 70]
# --- 0.51 minutes passed ---------
# 90
# 72
# 101
# 67
# 30
# 106
# 102
# 104
# 15
# 39
# 37
# 107
# 3
# 92
# 96
# 20
# 94
# 36
# 33
# 35
# ---------------------------------
# Similarity index       : 90
# Master Image file name : 98_0
# Nearest Neighbors.     : [90, 72, 101, 67, 30, 106, 102, 104, 15, 39, 37, 107, 3, 92, 96, 20, 94, 36, 33, 35]
# --- 0.51 minutes passed ---------
# 91
# 70
# 83
# 31
# 0
# 10
# 79
# 93
# 26
# 38
# 68
# 74
# 16
# 89
# 46
# 12
# 21
# 78
# 32
# 88
# ---------------------------------
# Similarity index       : 91
# Master Image file name : 95_0
# Nearest Neighbors.     : [91, 70, 83, 31, 0, 10, 79, 93, 26, 38, 68, 74, 16, 89, 46, 12, 21, 78, 32, 88]
# --- 0.51 minutes passed ---------
# 92
# 54
# 101
# 4
# 16
# 88
# 7
# 83
# 37
# 72
# 90
# 30
# 27
# 53
# 33
# 3
# 75
# 86
# 94
# 50
# ---------------------------------
# Similarity index       : 92
# Master Image file name : 73_3
# Nearest Neighbors.     : [92, 54, 101, 4, 16, 88, 7, 83, 37, 72, 90, 30, 27, 53, 33, 3, 75, 86, 94, 50]
# --- 0.51 minutes passed ---------
# 93
# 91
# 78
# 87
# 68
# 40
# 70
# 23
# 89
# 77
# 19
# 74
# 0
# 10
# 24
# 34
# 37
# 83
# 38
# 31
# ---------------------------------
# Similarity index       : 93
# Master Image file name : 69_0
# Nearest Neighbors.     : [93, 91, 78, 87, 68, 40, 70, 23, 89, 77, 19, 74, 0, 10, 24, 34, 37, 83, 38, 31]
# --- 0.51 minutes passed ---------
# 94
# 101
# 96
# 33
# 6
# 86
# 54
# 102
# 3
# 36
# 30
# 52
# 69
# 14
# 90
# 20
# 22
# 88
# 39
# 24
# ---------------------------------
# Similarity index       : 94
# Master Image file name : 63_0
# Nearest Neighbors.     : [94, 101, 96, 33, 6, 86, 54, 102, 3, 36, 30, 52, 69, 14, 90, 20, 22, 88, 39, 24]
# --- 0.51 minutes passed ---------
# 95
# 17
# 28
# 104
# 107
# 57
# 74
# 65
# 78
# 23
# 61
# 24
# 84
# 6
# 39
# 30
# 73
# 71
# 36
# 60
# ---------------------------------
# Similarity index       : 95
# Master Image file name : 90_0
# Nearest Neighbors.     : [95, 17, 28, 104, 107, 57, 74, 65, 78, 23, 61, 24, 84, 6, 39, 30, 73, 71, 36, 60]
# --- 0.51 minutes passed ---------
# 96
# 36
# 102
# 15
# 33
# 52
# 94
# 20
# 6
# 85
# 107
# 101
# 106
# 69
# 90
# 3
# 24
# 35
# 39
# 88
# ---------------------------------
# Similarity index       : 96
# Master Image file name : 75_0
# Nearest Neighbors.     : [96, 36, 102, 15, 33, 52, 94, 20, 6, 85, 107, 101, 106, 69, 90, 3, 24, 35, 39, 88]
# --- 0.51 minutes passed ---------
# 97
# 12
# 105
# 46
# 21
# 0
# 10
# 26
# 81
# 89
# 5
# 79
# 48
# 31
# 64
# 42
# 91
# 54
# 70
# 93
# ---------------------------------
# Similarity index       : 97
# Master Image file name : 97_0
# Nearest Neighbors.     : [97, 12, 105, 46, 21, 0, 10, 26, 81, 89, 5, 79, 48, 31, 64, 42, 91, 54, 70, 93]
# --- 0.51 minutes passed ---------
# 98
# 49
# 58
# 0
# 10
# 77
# 38
# 64
# 91
# 81
# 24
# 89
# 34
# 55
# 1
# 93
# 83
# 48
# 106
# 15
# ---------------------------------
# Similarity index       : 98
# Master Image file name : 84_0
# Nearest Neighbors.     : [98, 49, 58, 0, 10, 77, 38, 64, 91, 81, 24, 89, 34, 55, 1, 93, 83, 48, 106, 15]
# --- 0.51 minutes passed ---------
# 99
# 79
# 59
# 26
# 81
# 83
# 32
# 37
# 107
# 104
# 21
# 0
# 10
# 62
# 54
# 105
# 46
# 78
# 15
# 45
# ---------------------------------
# Similarity index       : 99
# Master Image file name : 98_3
# Nearest Neighbors.     : [99, 79, 59, 26, 81, 83, 32, 37, 107, 104, 21, 0, 10, 62, 54, 105, 46, 78, 15, 45]
# --- 0.51 minutes passed ---------
# 100
# 104
# 60
# 74
# 61
# 107
# 78
# 28
# 73
# 39
# 65
# 95
# 2
# 14
# 24
# 71
# 57
# 41
# 108
# 17
# ---------------------------------
# Similarity index       : 100
# Master Image file name : 56_0
# Nearest Neighbors.     : [100, 104, 60, 74, 61, 107, 78, 28, 73, 39, 65, 95, 2, 14, 24, 71, 57, 41, 108, 17]
# --- 0.51 minutes passed ---------
# 101
# 30
# 33
# 39
# 94
# 92
# 54
# 90
# 67
# 74
# 72
# 88
# 35
# 3
# 76
# 7
# 36
# 106
# 104
# 47
# ---------------------------------
# Similarity index       : 101
# Master Image file name : 66_0
# Nearest Neighbors.     : [101, 30, 33, 39, 94, 92, 54, 90, 67, 74, 72, 88, 35, 3, 76, 7, 36, 106, 104, 47]
# --- 0.51 minutes passed ---------
# 102
# 106
# 15
# 24
# 67
# 36
# 96
# 30
# 86
# 33
# 6
# 22
# 90
# 35
# 3
# 8
# 39
# 107
# 16
# 94
# ---------------------------------
# Similarity index       : 102
# Master Image file name : 79_0
# Nearest Neighbors.     : [102, 106, 15, 24, 67, 36, 96, 30, 86, 33, 6, 22, 90, 35, 3, 8, 39, 107, 16, 94]
# --- 0.51 minutes passed ---------
# 103
# 17
# 107
# 28
# 24
# 74
# 78
# 95
# 37
# 6
# 108
# 15
# 104
# 39
# 23
# 79
# 29
# 38
# 81
# 60
# ---------------------------------
# Similarity index       : 103
# Master Image file name : 83_0
# Nearest Neighbors.     : [103, 17, 107, 28, 24, 74, 78, 95, 37, 6, 108, 15, 104, 39, 23, 79, 29, 38, 81, 60]
# --- 0.51 minutes passed ---------
# 104
# 107
# 39
# 74
# 60
# 37
# 61
# 17
# 78
# 95
# 51
# 30
# 106
# 90
# 88
# 101
# 57
# 96
# 24
# 41
# ---------------------------------
# Similarity index       : 104
# Master Image file name : 98_1
# Nearest Neighbors.     : [104, 107, 39, 74, 60, 37, 61, 17, 78, 95, 51, 30, 106, 90, 88, 101, 57, 96, 24, 41]
# --- 0.51 minutes passed ---------
# 105
# 97
# 12
# 46
# 21
# 26
# 79
# 31
# 99
# 0
# 10
# 70
# 62
# 89
# 91
# 81
# 78
# 32
# 68
# 83
# ---------------------------------
# Similarity index       : 105
# Master Image file name : 101_0
# Nearest Neighbors.     : [105, 97, 12, 46, 21, 26, 79, 31, 99, 0, 10, 70, 62, 89, 91, 81, 78, 32, 68, 83]
# --- 0.51 minutes passed ---------
# 106
# 102
# 24
# 39
# 30
# 107
# 15
# 33
# 3
# 67
# 90
# 76
# 36
# 104
# 35
# 17
# 101
# 6
# 74
# 96
# ---------------------------------
# Similarity index       : 106
# Master Image file name : 74_0
# Nearest Neighbors.     : [106, 102, 24, 39, 30, 107, 15, 33, 3, 67, 90, 76, 36, 104, 35, 17, 101, 6, 74, 96]
# --- 0.51 minutes passed ---------
# 107
# 104
# 39
# 37
# 74
# 78
# 106
# 17
# 60
# 15
# 30
# 24
# 23
# 3
# 95
# 88
# 61
# 96
# 90
# 51
# ---------------------------------
# Similarity index       : 107
# Master Image file name : 98_2
# Nearest Neighbors.     : [107, 104, 39, 37, 74, 78, 106, 17, 60, 15, 30, 24, 23, 3, 95, 88, 61, 96, 90, 51]
# --- 0.51 minutes passed ---------
# 108
# 28
# 71
# 74
# 95
# 103
# 24
# 104
# 17
# 6
# 85
# 101
# 33
# 56
# 78
# 2
# 23
# 15
# 107
# 65
# ---------------------------------
# Similarity index       : 108
# Master Image file name : 88_0
# Nearest Neighbors.     : [108, 28, 71, 74, 95, 103, 24, 104, 17, 6, 85, 101, 33, 56, 78, 2, 23, 15, 107, 65]
# --- 0.51 minutes passed ---------
# 109
# 20
# 41
# 39
# 51
# 67
# 36
# 33
# 3
# 23
# 72
# 19
# 96
# 88
# 37
# 24
# 22
# 107
# 101
# 106
# ---------------------------------
# Similarity index       : 109
# Master Image file name : 92_0
# Nearest Neighbors.     : [109, 20, 41, 39, 51, 67, 36, 33, 3, 23, 72, 19, 96, 88, 37, 24, 22, 107, 101, 106]
# --- 0.51 minutes passed ---------
# Step.2 - Similarity score calculation - Finished
# Step.3 - Data stored in 'nearest_neighbors.json' file
# --- Prosess completed in 0.51 minutes ---------
